# %%
import os
import csv
import pandas as pd

# %%
html_table_data = pd.read_csv("cities.csv")
html_table_data.head()
# Out:
#    City ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0     jamestown           1      US  1595722676        64  42.10
# 1        1      goderich          98      CA  1595722888        60  43.75
# 2        2    port hardy           0      CD  1595722888        41  -7.03
# 3        3     manzhouli          95      CN  1595722888        75  49.60
# 4        4  puerto ayora           0      ES  1595722889        69  36.59
#
#       Lng  Max Temp  Wind Speed
# 0  -79.24     75.20        8.05
# 1  -81.72     78.01        4.00
# 2   29.76     68.14        6.13
# 3  117.43     71.76       10.80
# 4   -6.23     80.01        2.24

# %%
print(html_table_data.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>jamestown</td>
#       <td>1</td>
#       <td>US</td>
#       <td>1595722676</td>
#       <td>64</td>
#       <td>42.10</td>
#       <td>-79.24</td>
#       <td>75.20</td>
#       <td>8.05</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>goderich</td>
#       <td>98</td>
#       <td>CA</td>
#       <td>1595722888</td>
#       <td>60</td>
#       <td>43.75</td>
#       <td>-81.72</td>
#       <td>78.01</td>
#       <td>4.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>port hardy</td>
# ...
